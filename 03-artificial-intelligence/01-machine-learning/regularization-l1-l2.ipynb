# %% [markdown]
# # L1 Penalty and Sparsity
#
# ## L1 Panalty and Sparsity in Logistic Regression
# https://scikit-learn.org/stable/auto_examples/linear_model/plot_logistic_l1_l2_sparsity.html
# ![image.png](attachment:b1d05906-f774-484e-9db7-7968d0217230.png)
