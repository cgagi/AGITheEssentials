# %% [markdown]
# # Linear Algebra
# - Linear Combinations & Span

# %% [markdown]
# # Linear Combination & Span
# - two vectors v and w
# - linear combination a * v + b * w
# - linear dependency and independency v = a * w or v != a * w
# - span all possible vectors u = a * v + b * w
# - basis vectors i and j

# %% [markdown]
# # Linear Transformation
# - linear transformation as a function v - vector , L(v) = output vector
# - space transformation two basis vectors of a matrix
# ![image.png](attachment:9eddadbb-bcfc-488e-a595-e7851c76ba3f.png)
# ![image.png](attachment:4fbb3b38-395d-426d-b8c8-48f67671e5ad.png)
# ![image.png](attachment:f8ef4be8-c944-4c28-8bcc-ec8e0eb47459.png)
# ![image.png](attachment:d8a3476d-2952-489c-afa0-2a855a87accd.png)
# ![image.png](attachment:c8561090-746c-463f-b905-6bda62b51429.png)

# %% [markdown]
# # Eigenvectors, Eigenvalues and Eigenbasis

# %%
import numpy as np

A = np.array([[3, 1],[0, 2]])

# %% [markdown]
# ## Determinant

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Scatter(x=[0,1,4,3,0], y=[0,2,2,0,0], fill="toself"))
fig.show()

# %%
np.linalg.det(A)
# Out:
# 6.0

# %%
# Out:
# 6.0

# %%
w, v = np.linalg.eig(A)
w, v
# Out:
# (array([3., 2.]),
#  array([[ 1.        , -0.70710678],
#         [ 0.        ,  0.70710678]]))

# %%
np.dot(A, [-1, 1])
# Out:
# array([-2,  2])

# %%
np.det()
