# %% [markdown]
# # U-Net for brain MRI
# U-Net with batch normalization for biomedical image segmentation with pretrained weights for abnormality segmentation in brain MRI
# Source: https://pytorch.org/hub/mateuszbuda_brain-segmentation-pytorch_unet/
# ![image.png](attachment:image.png)

# %%
import torch
model = torch.hub.load('mateuszbuda/brain-segmentation-pytorch', 'unet', 
                       in_channels=3, out_channels=1, init_features=32, pretrained=True)
# Out:
# Downloading: "https://github.com/mateuszbuda/brain-segmentation-pytorch/archive/master.zip" to /home/host/.cache/torch/hub/master.zip
# Downloading: "https://github.com/mateuszbuda/brain-segmentation-pytorch/releases/download/v1.0/unet-e012d006.pt" to /home/host/.cache/torch/hub/checkpoints/unet-e012d006.pt
